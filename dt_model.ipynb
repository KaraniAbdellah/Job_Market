# %%
# Regression Model:
'''
    Build a Model That Predicat the salary based on:
        --> city, occupation, field, years_of_experience, employment_type, education_level, gender, company_size
'''
