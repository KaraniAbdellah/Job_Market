# %%
import joblib
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# Load The Model
model = joblib.load("./my_model.pkl")
model
# Out:
# /home/abdellah/.local/lib/python3.12/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeRegressor from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/abdellah/.local/lib/python3.12/site-packages/sklearn/base.py:463: InconsistentVersionWarning: Trying to unpickle estimator RandomForestRegressor from version 1.6.1 when using version 1.8.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# RandomForestRegressor(oob_score=True)

# %%
# Get Test Set
X_train = pd.read_csv("./data/X_train.csv")
y_train = pd.read_csv("./data/y_train.csv")
X_test = pd.read_csv("./data/X_test.csv")
y_test = pd.read_csv("./data/y_test.csv")

# Get First Row
firstTwoRows = X_test.iloc[0:2]
firstTwoRows
# Out:
#    years_of_experience  education_level  gender  company_size  field_Business  \
# 0                   17                0       1             3            True
# 1                    1                0       1             3           False
#
#    field_Design  field_Finance  field_Human Resources  field_Marketing  \
# 0         False          False                  False            False
# 1         False          False                  False            False
#
#    field_Operations  ...  occupation_Cloud Engineer  occupation_Data Analyst  \
# 0             False  ...                      False                    False
# 1             False  ...                       True                    False
#
#    occupation_Data Scientist  occupation_Financial Analyst  \
# 0                      False                         False
# 1                      False                         False
#
#    occupation_HR Analyst  occupation_Marketing Specialist  \
# ...

# %%
# Prediction
model.predict(firstTwoRows)
# Out:
# array([161084.09,  99619.86])

# %%
import pandas as pd
data = {"key1": "Switzerland","key2": 3,"key3": 4}
df = pd.DataFrame(list(data.items()), columns=["Key", "Values"])
print(df)
# Out:
#     Key       Values
# 0  key1  Switzerland
# 1  key2            3
# 2  key3            4

# %%
row_dict = {
    "country": "Switzerland",
    "city": "Zurich",
    "occupation": "Operations Manager",
    "field": "Operations",
    "years_of_experience": 16,
    "salary": 359609.0,
    "employment_type": "work_from_home",
    "education_level": "Master",
    "gender": "Male",
    "company_size": "Large"
}
cp_data = pd.DataFrame(data=[row_dict])
cp_data
# Out:
#        country    city          occupation       field  years_of_experience  \
# 0  Switzerland  Zurich  Operations Manager  Operations                   16
#
#      salary employment_type education_level gender company_size
# 0  359609.0  work_from_home          Master   Male        Large

# %%
from sklearn.preprocessing import OneHotEncoder # for One Hot Encoding

# %%
# Mapping/Label Encoding This Varaibles
company_size_map = {'Large': 3, 'Enterprise': 2, 'Medium': 1, 'Small': 0}
cp_data["company_size"] = [company_size_map.get(v) for v in cp_data["company_size"]]

gender_map = {'Male': 0, 'Female': 1, 'Other': 2}
cp_data["gender"] = [gender_map.get(v) for v in cp_data["gender"]]

education_level_map = {'PhD': 3, 'Master': 2, 'Bachelor': 1, 'High School': 0}
cp_data["education_level"] = [education_level_map.get(v) for v in cp_data["education_level"]]

# One-Hot-Encoding
one_hot_encoder = OneHotEncoder()
cp_data = pd.get_dummies(cp_data, columns=["field", "employment_type", "city", "country", "occupation"])
cp_data.head(3)
# Out:
#    years_of_experience    salary  education_level  gender  company_size  \
# 0                   16  359609.0                2       0             3
#
#    field_Operations  employment_type_work_from_home  city_Zurich  \
# 0              True                            True         True
#
#    country_Switzerland  occupation_Operations Manager
# 0                 True                           True

# %%
# Add More Columns
all_features = model.feature_names_in_
for f in all_features:
    if (cp_data.get(f) is None):
        cp_data[f] = False
cp_data.columns
# Out:
# Index(['country', 'city', 'occupation', 'field', 'years_of_experience',
#        'salary', 'employment_type', 'education_level', 'gender',
#        'company_size', 'field_Business', 'field_Design', 'field_Finance',
#        'field_Human Resources', 'field_Marketing', 'field_Operations',
#        'field_Technology', 'employment_type_freelance',
#        'employment_type_full_time', 'employment_type_internship',
#        'employment_type_part_time', 'employment_type_work_from_home',
#        'city_Amsterdam', 'city_Auckland', 'city_Bangalore', 'city_Berlin',
#        'city_Cape Town', 'city_Dubai', 'city_Dublin', 'city_London',
#        'city_Madrid', 'city_Mexico City', 'city_Milan', 'city_New York',
#        'city_Paris', 'city_San Francisco', 'city_Sao Paulo', 'city_Seoul',
#        'city_Singapore', 'city_Stockholm', 'city_Sydney', 'city_Tokyo',
#        'city_Toronto', 'city_Zurich', 'country_Australia', 'country_Brazil',
# ...

# %%
model.predict(cp_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 model.predict(cp_data)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:1065, in ForestRegressor.predict(self, X)
#    1063 check_is_fitted(self)
#    1064 # Check data
# -> 1065 X = self._validate_X_predict(X)
#    1067 # Assign chunk of trees to jobs
#    1068 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~/.local/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:637, in BaseForest._validate_X_predict(self, X)
#     634 else:
#     635     ensure_all_finite = True
# --> 637 X = validate_data(
#     638     self,
#     639     X,
#     640     dtype=DTYPE,
#     641     accept_sparse="csr",
#     642     reset=False,
#     643     ensure_all_finite=ensure_all_finite,
#     644 )
# ...

# %%
print(cp_data.get("XY"))
# Out:
# None
