# %% [markdown]
# ## Get The Data From API

# %%
# Import Packages
import requests
import json
from openpyxl import Workbook
import pandas as pd
from pprint import pprint

# %%
# API-ENDPOINT
numberOfDocument = 1
numberOfRow = 1000
URL = f"https://api.fda.gov/drug/event.json"

# %%
# Load Data
req = requests.get(url=URL, params={'limit': numberOfDocument})
data = req.json()
dict_data = data["results"][0]

df1 = pd.json_normalize(data=dict_data) # normalize json data
df2 = df1.melt() # flip the data vertically
df2
# Out:
#                                        variable  \
# 0                                safetyreportid
# 1                        transmissiondateformat
# 2                              transmissiondate
# 3                                       serious
# 4                              seriousnessdeath
# 5                             receivedateformat
# 6                                   receivedate
# 7                             receiptdateformat
# 8                                   receiptdate
# 9                       fulfillexpeditecriteria
# 10                                  companynumb
# 11                                     receiver
# 12                primarysource.reportercountry
# 13                  primarysource.qualification
# 14                    sender.senderorganization
# 15                      patient.patientonsetage
# 16                  patient.patientonsetageunit
# 17                           patient.patientsex
# 18  patient.patientdeath.patientdeathdateformat
# 19        patient.patientdeath.patientdeathdate
# 20                             patient.reaction
# 21                                 patient.drug
#
#                                                 value
# 0                                           5801206-7
# 1                                                 102
# 2                                            20090109
# 3                                                   1
# 4                                                   1
# 5                                                 102
# 6                                            20080707
# 7                                                 102
# 8                                            20080625
# 9                                                   1
# 10                                         JACAN16471
# 11                                               None
# 12                                             CANADA
# 13                                                  3
# 14                                     FDA-Public Use
# 15                                                 26
# 16                                                801
# 17                                                  1
# 18                                               None
# 19                                               None
# 20  [{'reactionmeddrapt': 'DRUG ADMINISTRATION ERR...
# 21  [{'drugcharacterization': '1', 'medicinalprodu...

# %%
# Export it to CSV
df1.to_csv("data.csv", index=False) # remove index (0, 1, 2, ... n)

# %%
# Test code
from pprint import pprint

with open("./data.json") as f:
    data = json.load(f)

df = pd.json_normalize(data=data)
df1 = df.explode(["patient.drug"])
df2 = df.explode(["patient.reaction"])

# Explode Array
df1_patient_drug = pd.json_normalize(data=df1["patient.drug"])
df1_patient_reaction = pd.json_normalize(data=df2["patient.reaction"])
df1_patient_reaction_0 = pd.json_normalize(data=df1_patient_reaction[0])
df1_patient_reaction_1 = pd.json_normalize(data=df1_patient_reaction[1])

# # Drop Column
df = df.drop("patient.drug", axis=1)
df = df.drop("patient.reaction", axis=1)

# Combine Dataframes
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File /usr/lib/python3/dist-packages/pandas/_libs/index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/lib/python3/dist-packages/pandas/_libs/index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[229], line 14
#      12 df1_patient_drug = pd.json_normalize(data=df1["patient.drug"])
#      13 df1_patient_reaction = pd.json_normalize(data=df2["patient.reaction"])
# ---> 14 df1_patient_reaction_0 = pd.json_normalize(data=df1_patient_reaction[0])
#      15 df1_patient_reaction_1 = pd.json_normalize(data=df1_patient_reaction[1])
#      17 # # Drop Column
#
# File /usr/lib/python3/dist-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /usr/lib/python3/dist-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 0
