# %% [markdown]
# ## Tasks

# %%
# Build An API
# Build WebSite
# Power BI DashaBaord

# %% [markdown]
# ## DataSet Desciption

# %%
# Characteristic: clean dataset, not missing values, not real dataset
# Columns
'''
    - country
    - city
    - Job & Industry:
        --> occupation: job_name/role (Software Engineer, HR Analyst, ...)
        --> field: The broader professional domain for the occupation (Technology, ...)

    - Experience & Salary Variables:
        --> years_of_experience
        --> salary
        --> experience
        --> job field
        --> occupation type
        --> location

    - Employment & Education Variables
        --> employment_type (full_time, part_time, freelance, ...)
        --> education_level

    - Demographics & Company Variables
        --> gender
        --> company_size
'''

# %% [markdown]
# ## Ressources

# %%
# https://www.kaggle.com/datasets/kundanbedmutha/job-market-dataset-global
# https://www.youtube.com/watch?v=U-JlXWDqvco

# %%
import pandas as pd

# %%
data = pd.read_csv("./data/job_market_dataset.csv")

# %%
# data["occupation"].unique()
# data["city"].unique()
# data["field"].unique()
# data["employment_type"].unique()
# data["education_level"].unique()
# data["gender"].unique()
data["company_size"].unique()
# Out:
# array(['Large', 'Enterprise', 'Medium', 'Small'], dtype=object)
